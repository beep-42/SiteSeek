# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
from sklearn.metrics import RocCurveDisplay

sns.set(rc={'figure.figsize':(11,8)}) 
sns.set_style('whitegrid')

# %%
with open('ProSPECCTs results/NMR_structures.pickle', 'rb') as f:
    dataset = pickle.load(f)

df = pd.DataFrame.from_dict(dataset) #, orient='index')
df
# Out:
#            score                                                rot  \
# 0       2.634285  [[1.0, 8.9241414e-10, -2.4961615e-09], [8.9241...
# 1       2.406073  [[0.9995363, -0.012552723, -0.027742349], [0.0...
# 2       0.266000  [[0.29291338, -0.07243383, 0.9533913], [-0.903...
# 3       0.696800  [[0.8749262, -0.17683715, 0.45081344], [0.2750...
# 4      -0.587193  [[-0.50544244, 0.8555256, -0.11226746], [0.857...
# ...          ...                                                ...
# 108236 -1.000000                                                NaN
# 108237 -1.000000                                                NaN
# 108238 -1.000000                                                NaN
# 108239 -1.000000                                                NaN
# 108240 -1.000000                                                NaN
#
#                                            trans     label   ligand_dist
# 0                      [0.0, 1.1920929e-07, 0.0]  positive  1.043081e-07
# 1          [-0.221838, 0.0007369518, 0.06803465]  positive  1.854080e-01
# 2          [-0.020357132, 0.35813057, 0.5498533]  positive  9.913449e-01
# 3       [0.022798061, -0.0042824745, 0.40366757]  positive  6.563978e-01
# 4            [0.2938366, -0.6723622, -0.4411173]  positive  1.100106e+00
# ...                                          ...       ...           ...
# 108236                                       NaN  negative           NaN
# 108237                                       NaN  negative           NaN
# 108238                                       NaN  negative           NaN
# 108239                                       NaN  negative           NaN
# 108240                                       NaN  negative           NaN
#
# [108241 rows x 5 columns]

# %%
print(f"Found correct: {df[(df.label == 'positive') & (df.ligand_dist < 1)].count()} out of {sum(df.label == 'positive')}")
# Out:
# Found correct: score          5825
# rot            5825
# trans          5825
# label          5825
# ligand_dist    5825
# dtype: int64 out of 7729

# %%
sns.scatterplot(df[df.score < 100], x='score', y='ligand_dist', hue='label')
# Out:
# <Axes: xlabel='score', ylabel='ligand_dist'>

# %%
sns.histplot(df, x='score', hue='label', stat='percent', common_norm=False)
# Out:
# <Axes: xlabel='score', ylabel='Percent'>

# %%
sns.histplot(df[df.score < 100], x='score', hue=df.ligand_dist < 1, stat='percent', common_norm=False)
# Out:
# <Axes: xlabel='score', ylabel='Percent'>

# %%
print("Positive results:", sum(df.ligand_dist < 5))
RocCurveDisplay.from_predictions(list(df.ligand_dist < 5), list(df.score))
# Out:
# Positive results: 6938

# %%
print('Total expected:', sum(df.label == 'positive'))
adjusted = [row.score if row.label == 'negative' or row.ligand_dist < 1 else -1 for i, row in df.iterrows()]
RocCurveDisplay.from_predictions(df.label == 'positive', adjusted, plot_chance_level=True)
